# %% [markdown]
# # Project Log
#
# Student: Joanna (1962)
# Age: 16
# Email:  n/a
#
# # DUE DATE: APRIL 24th 5:00PM
#
# Project Submission !!!: https://docs.google.com/document/d/1jyJrI7SA9TGWLddVhnkfORIpTiL3LE4VISeOgpXRgDo/edit#heading=h.15onh5s03h71
#
# Links and Resources:
# Quest Link: https://quest.codingmind.com/view/A37483D588F64A218BDA8136A4
# Project Log: https://docs.google.com/presentation/d/1vYF-IvyX2jcHzy3-8f7b-Ft1LCD_yueLYusj7SxVKN8/edit#slide=id.g165972af664_0_0
# Project GitHub: https://github.com/Chuqiao-Peng/Eureka
# Parts List: https://docs.google.com/document/d/1Ifyk6Y6iHjwtEOsW6inxFJiSGfYUxcCGRjgiDmbCUeE/edit#heading=h.3sfginsyp6i1
#
# Particle Account:
# chuqiao0727@gmail.com
# Eureka1234
# access_token: 40c9617030f65832904eb99528de3da5e7ebfe66

# %% [markdown]
# ## Session 1: Thursday 11/16
#
# Introductions
# Overview of Project
#
# Overview of tools and equipment
# - install any languages or IDE
# - create github acc
#
#
# Python Assessment and Review
#
# Machine Learning
#
# End Statements: We installed flutter and will be learned about app development first. Joanna was going to design her app using Canva or Figma before we try to recreate it in Flutter. She was introduced to basic widgets and the scaffolding.

# %% [markdown]
# ## Session 2: Tuesday 11/21
#
# Flutter App Development
#
# Install LiveShare
#
# Review Widgets in Quest
#
# Reorganize and separate files and classes
# Learn how to navigate to a new screen
# Learn about splash screen
# Learn about custom widgets
# Learn about pubspec.yaml and libraries
#
# Misc:
# - IDE Wrapping and Refactoring
# - Showing WireFrames
# - Finding possible modifications to a widget
#
# Work towards design
# - how should information be displayed?
# - what type of information should appear?

# %% [markdown]
# ## Session 3: Tuesday 11/28
#
# Recreate and polish app design.
# - Rounded purple text field
# - Black button
# - Obscure Icon
#
# Login Screen
#
# Better Splash page
#
# Additional Screens
# - What kind of Menus?
#
#
# Upload first project to github.
# - Downloading git and creating account on GitHub

# %% [markdown]
# ## Session ??: Friday 12/22
#
# Focus of today: Create NewsPage and learn about new hardware
# Secondary: Prototype ReportPage
#     Talk about the messages/warnings that reports will display
#
# Talk about new EKG Hardware
# - go through parts list
#
#
# Showcase the design of newspage
#
# Design newspage
# - push current version to github and work from Eureka workspace or liveshare
#
# Prototype ReportPage
# Utilize messages/warnings
# Draft what kind of information should be recieved? (Literature Review)
# How will each information be displayed?
#
#
#
# Prep work
# - find status of github
# - import working current version of github
#
# - review newspage
#
# - https://infiniummedical.com/how-do-electrocardiogram-machines-work/
# - look at ecg hardware information
#     - https://learn.sparkfun.com/tutorials/ad8232-heart-rate-monitor-hookup-guide?_gl=1*19hk33l*_ga*ODY1NDAzMzAzLjE3MDQ4NDE5NTU.*_ga_T369JS7J9N*MTcwNDg0MTk1NS4xLjEuMTcwNDg0MjU5Mi40MS4wLjA.&_ga=2.75070998.563958600.1704841955-865403303.1704841955
# - Heart Monitor Sensor - https://www.sparkfun.com/videos#all/rjWXtpbgLKg/158
#     - sensor (https://www.sparkfun.com/products/12650)
#     - cables (https://www.sparkfun.com/products/12970)
#     - electrodes (https://www.sparkfun.com/products/12969)
#
# - prototype reportpage
# - create dummy data for report page and buttons

# %% [markdown]
# ## Session 12: Tuesday 1/26/2024
#
# Finish Authentication
# - firebase authentication
# - login page
# - signup page

# %% [markdown]
# ## Session 13: Tuesday 1/23/2024
#
# Look for more classes to fulfill project needs?
#
# Issues with installing pod (error in email)
# - https://stackoverflow.com/questions/54135078/how-to-solve-error-running-pod-install-in-flutter-on-mac
# Unable to install gRPC-Core (1.49.1)
# - https://stackoverflow.com/questions/76530849/pod-install-getting-stuck-grpc-core-1-50-1

# %% [markdown]
# ## Session 14: Tuesday 1/30/2024
#
# Hook Up Example: https://learn.sparkfun.com/tutorials/ad8232-heart-rate-monitor-hookup-guide
# Particle Boron Datasheet: https://docs.particle.io/reference/datasheets/b-series/boron-datasheet/
# Heart Sensor Datasheet: https://www.sparkfun.com/products/12650?_ga=2.18048249.1147361224.1706659316-1017615498.1706659316&_gl=1*1c9stam*_ga*MTAxNzYxNTQ5OC4xNzA2NjU5MzE2*_ga_T369JS7J9N*MTcwNjY1OTMxNS4xLjAuMTcwNjY1OTMxNS42MC4wLjA.
#
# ### Hardware Assembly and Testing
#
# Parts
# - Particle Boron
# - Heart Rate Sensor
# - Electrode pads and cable
#
# Flashing a program into the Boron
# - create account
# - Web IDE
# - blink test
#
# Assembling the Particle Boron with Heart Sensor
# - Understanding the breadboard (https://learn.sparkfun.com/tutorials/how-to-use-a-breadboard/all)
# - Review Circuit Schematics (hook up example)
# - Assemble and obtain analog reading from sensor
# - Plot analog reading with Processing or Serial Plotter (???)
#
# Integrate Boron with Firebase
# - Add user to firebase
# - Create webhook
# - Test out webhook with sample data
# - Use webhook to save reading from heart sensor
#
# Intro to Machine Learning
# - Classifiers and sci-kit learn

# %% [markdown]
# ## Session 16: Tuesday 2/6/2024
#
# Read and review introduction in research paper
#
# Install and use particle workbench
#
# Integrate Boron with Firebase
# - create new webhook
# - flash with workbench
# - publish small counter
#
# Hook up Boron with Heart Sensor
# - read and view serial monitor
# - view data in processing
#
# Cover particle functions
# - cover simple function
#     - showcase using Postman
#     - Access token: https://docs.particle.io/reference/cloud-apis/access-tokens/
#     - Functions: https://docs.particle.io/reference/device-os/api/cloud-functions/particle-function/
# - cover function with parameters (LED Example)
# - work on heart-rate function that can be triggered remotely

# %% [markdown]
# ## Session 17: Thursday 2/8/2024
#
# Read and review introduction of research paper
#
# Create particle function for Heart Sensor
# - Declare function
# - Function algorithm or operation
# - Publish data to Firebase
#
# Call particle API on Flutter
# - install http library
# - https://docs.flutter.dev/cookbook/networking/fetch-data
# - send POST request (email example)
#
# Use HTTP to read news from server
# - http (fitness example)
#
# Read ekg data from Firebase

# %% [markdown]
# ## Session 18: Tuesday 2/13/2024
#
# Read and review research paper methodology
#
# Pin Difference
# - explain difference
# - implement
# - test and view
#
# Breaking down dataset
# - https://physionet.org/content/ecgrdvq/1.0.0/
# - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1122339/#:~:text=The%20arrangement%20of%20the%20leads,into%20the%20cavity%20of%20the
# - Explain the 12 leads
# - Which lead should we focus on?
#
# Install WFDB Python Package and read dataset
# - https://archive.physionet.org/faq.shtml
# - https://pypi.org/project/wfdb/0.1.2/
# - https://github.com/MIT-LCP/wfdb-python
# - Comparison of values from dataset and readings from sensor
#
# Quick Numpy Lesson (manipulate and view large data structures)
# - https://numpy.org/doc/stable/user/quickstart.html
# - Basic Numpy Operations
#
# Organize user information and database?
# - Receive news information from the server
# - maintain and organize user data

# %% [markdown]
# ## Session 19: Thursday 2/15/2024
#
# Integrate server news with flutter app  [x]
# - create NewsSection using FutureBuilder [x]
#
# Flutter to Firebase Database
# - create user collection
# - create document with user profile
# - insert document to user collection
# - create report collection w/ dummy value
#
# Assemble Training Data for Machine Learning
# - OS / io

# %% [markdown]
# ## Session 20: Wednesday 2/21/2024
#
# Flutter to Firebase Database
# - create user collection
# - create document with user profile
# - insert document to user collection
# - create report collection w/ dummy value
# - https://quest.codingmind.com/view/A37483D588F64A218BDA8136A4 (CRUD section)
#
# Pandas and Numpy Quickstart???
# - creating a numpy array
# - numpy operations
# - numpy indexing
# - creating panda (dataframe and series)
# - panda operations
# - panda indexing
# - panda read and load csv
#
# EKG Classifier
# - Assemble matrix of LEAD II for each subject (each_subject.py)
# - Assemble all matrixes from each subject (data_compile.py)
#     - Iterate through each subject
#     - merge/map subject data to csv
#     - save compiled_dataset.csv
# - Format into training data and training label (svm_test.py)
#     - Fit training data set into model
#     - save trained model
#     - save encoder
#
# Testing
# - Get heart sample, 10,000 reading
# - load model and encoder
# - Assemble input_data for model to make prediction
# - Predict condition based on input_data
#
# Save and load Model using Pickle (https://stackoverflow.com/questions/56107259/how-to-save-a-trained-model-by-scikit-learn)
#
# Examine Data and Test
# - discuss discrepencies
#     - vectors and characteristics
#     - different starting points hence different phases get compared
#     - iris example
#     - mV to (0-4095)units 5V
# - feature extraction from ecg reading (plot_heart_reading.py)
#     - https://en.wikipedia.org/wiki/Automated_ECG_interpretation
# - normalize data
#     - perform numpy operations
# - ecg interpreter (neurokit_example.py)
#     - https://medium.com/@lalesena/how-to-analyze-ecgs-with-python-396e34ece937
#     - https://neuropsychology.github.io/NeuroKit/functions/ecg.html
# - ecg viewer
#     - https://github.com/HTM-Workshop/ECG-Viewer
#
# Create route to access model in Flask

# %% [markdown]
# ## Session 21: Thursday 2/22/2024
#
# Flutter to Firebase Database
# - create user collection
# - create document with user profile
# - insert document to user collection
# - create report collection w/ dummy value
# - https://quest.codingmind.com/view/A37483D588F64A218BDA8136A4 (CRUD section)
#
# EKG Classifier (load_model.py)
# - load encoder and model
# - gather input_data
# - predict input_data
# - decode prediction
#
# Examine Data and Test (plot_heart_reading.py)
# - discuss discrepencies
#     - examine input data
#         - different starting points hence different phases get compared
#         - identify characteristics
#     - iris example
#     - mV to (0-4095)units 5V
# - feature extraction from ecg reading
#     - https://en.wikipedia.org/wiki/Automated_ECG_interpretation
#     - build basic input_data stats???
#         - [peak amplitude, areas under the curve, time delays, heart rate frequency, sex, weight, height, race]
#
# Using neurokit for ecg analysis (neurokit_example.py)
# - install neurokit
# - perform a quickstart
# - examine results (signal and info) of .ecg_process()
# - go through the functions to identify helpful values
# - https://medium.com/@lalesena/how-to-analyze-ecgs-with-python-396e34ece937
# - https://neuropsychology.github.io/NeuroKit/functions/ecg.html
#
# Getting the average heartbeat (neurokit_testing.py)
# - view neurokit GitHub Repository
# - https://github.com/neuropsychology/NeuroKit/tree/master
#
# Process ecg data for key features (data_process.py)
# - load in relevant data
# - create dataframe to hold relevent information
# - process ecg signals for key features
# - add key features to dataframe
# - make sure to encode any non_numerical columns
#
# ecg viewer
# https://github.com/HTM-Workshop/ECG-Viewer
# normalize data
# perform numpy operations

# %% [markdown]
# ## Session 22: Tuesday 2/27/2024
#
# Learning how to process data and extract features from a large dataset
#
# Organizing Data and Preparing it for Processing (data_process.py)
# - extract person characteristics from csv
# - create columns identifying important characteristics
# - create dataframe to contain person characteristics
#     - pandas
# - use label encoder to numerize columns
#
# Creating average heartbeat function (create file for it)
#
# Extracting R Peaks (data_process_r_peaks.py)
# - extract ecg readings from csv
# - how to get average r-peaks from each reading
# - add average r-peaks column to dataframe
# <!-- - distinguish between r-peak of average heartbeat and average of all r-peaks??? -->
#
# Extracting PR Intervals (data_process_pr_intervals.py)
# - extract ecg readings from csv
# - how to get average pr-intervals from each reading
# - add average pr-intervals column to dataframe
#
# Creating a process to extract important features from our data (data_process_final.py)
# - find ways to extract more characteristics
# - save and load label encoders
#
#
# <!-- nk functions to go over
# ecg_delineate()
# ecg_peaks()??? -->

# %% [markdown]
# ## Session 23: Thursday 2/29/2024
#
# Check Homework
# - check on any new updates
# - check on research paper
# - check on p-wave calculation
#     - using integration
# - attempt to integrate with data_process
#
# Continue with [data_process_final.py]
# - integrate p-wave area
# - save encoders used
# - attempt to process entire dataset
# - debug issues with ZeroDivision [csv_process.py]
# - save to csv
#
# Train new model [train_model_v2.py]
# - read from processed_dataset.csv
# - seperate training data and training label
#     - use [iris_example.py] as example
# - train and save model
#
# Test new model [test_model_v2.py]
# - load model and any necessary encoders
# - gather input_data and process for characteristics
# - arrange dataframe for input prediction
# - use model to make a prediction
#
# Get test input from Joanna?
#
# Implement EKGClassifier into Flask server  [ecgclassifier.py] [server.py]
# - simply [test_model_v2.py] into a function
#     - consider inputs and outputs
# - import function into [server.py]
# - correctly load models and encoders into server
# - create route for ecg classifier
#     - load request content as function arguments
#
# Flutter to Firebase Database
# - create user collection
# - create document with user profile
# - insert document to user collection
# - create report collection w/ dummy value
# - https://quest.codingmind.com/view/A37483D588F64A218BDA8136A4 (CRUD section)
#
# Create page to edit profile settings

# %% [markdown]
# ## Session 24: Wednesday
#
# Train and test new model
# - finish compiling processed dataset, models, and encoders
# - test sample input and obtain result [test_model_v2.py]
#     - make sure to make use of encoders
#
# Implement EKGClassifier into Flask server  [ecgclassifier.py] [server.py]
# - simplify [test_model_v2.py] into a function
#     - consider inputs and outputs
# - import function into [server.py]
# - correctly load models and encoders into server
# - create route for ecg classifier
#     - load request content as function arguments
# - update [server.py] to run on all addresses
#     - app.run(host='0.0.0.0', debug=True)
# - Test in postman for accurate response
#
# ### Host Flask server to AWS (https://www.youtube.com/watch?v=5gSG5jwOJSY)
# #### Connect to Server
# ```bash
# ssh -i "ecg_key.pem" ec2-user@ec2-52-10-165-77.us-west-2.compute.amazonaws.com
# ```
#
# #### Transfer Files:
# ``` bash
# scp -i "ecg_key.pem" BackendCode/server.py ec2-user@ec2-52-10-165-77.us-west-2.compute.amazonaws.com:/home/ec2-user/server/
# ```
# - requirements.txt
# - ecgclassifier.py
# - server.py
# - news_data.py
# - encoders.pkl
# - model.pkl
#
# In terminal
# - update software
#     - sudo yum update (openssl)
# - install any system packages / software
#     - sudo yum install (git)
# - update inbound security rules
#     - open port 5000
#
# Test in Postman
#
# Organize UserData in Firebase Database [signuppage.dart]
# - create [SignUp] function for button
# - prepare some dummy user information
# - create user collection
# - create document with user profile
# - insert document to user collection
# - create report collection w/ dummy value
# - https://quest.codingmind.com/view/A37483D588F64A218BDA8136A4 (CRUD section)
#
# Update UserData in Firebase [profilepage.dart]
# - create new profile page
# - add textfields to accept input from user
# - create function to update user values
#
# Pulling user data for reports
# - update [reportlistpage.dart]
# - query list of reports from user's reports collection
# - sort report ids
# - display report ids in report row
#     - use future builder

# %% [markdown]
# ## Session 27: Thursday 3/14/2024
#
# Create Profile Page and Update Values in DB [profilepage.dart]
#
# Implement working bottom nav bar [masterpage.dart]
#
# Implement reports
# - showcase graphing library [reportlistpage.dart/topwindow]
# - https://pub.dev/packages/fl_chart
#
# Refactor authentication for user [main.dart]
# - use User object uid for doc reference in db [signuppage.dart] [homepage.dart] [reportlistpage.dart] [profilepage.dart]
# - persistent login and sign out option [splashpage.dart] [profilepage.dart/signout]

# %% [markdown]
# ## Session 28: Wednesday 3/20/2024
#
# Finish creating profile page [profilepage.dart]
# - use text controllers and text fields
# - submit data and update user info in database
#
# Create weekly reports [reportweeklistpage.dart]
# - refactor how data is organized in firebase
#     - change [signuppage.dart]
#     - change [homepage.dart/SubmitSampleReports()]
# - create sample entry

# %% [markdown]
# ## Session 29: Thursday 3/21/2024
#
# Finish up [reportweeklistpage.dart]
# - sort weekly_report documents [reportweeklistpage.dart/weeklySort()]
# - navigate to report list page
#
# Refactor [reportlistpage.dart]
# - how to query from new collection?
#     - what info is needed? [week#]
# - sort report
# - navigate report to display chart
#
# Install and import [fl_chart]
# - installation and download
#     - https://pub.dev/packages/fl_chart
# - query avg_heartbeat
# - plot avg_heartbeat [reportpage.dart]
# - [LineChart()]
# - [generatePoints()]
#
# Connect Diagnose Button with particle boron
# - update boron software
# - gather ecg signal
# - compress ecg signal to 12 bits
# - convert ecg signal to base64
# - publish ecg signal to realtime firebase
#
# Cloud functions
# - https://firebase.google.com/docs/functions/get-started?gen=2nd#python
# - create a cloud function to store and organize user's ecg signals
# - send signals to server to be processed
# - realtime database to cloud firestore
# - deploy functions (https://firebase.google.com/docs/functions/manage-functions?gen=2nd)
# - upgrade Eureka project to Blaze plan

# %% [markdown]
# ## Session 30: Wednesday 3/27/2024
#
# Focus: Implementing "Diagnose Now" to record signals in user database
#
# 1) Dianose Now triggers function in Particle Boron [x]
# 2) Particle Boron detects readings from heart sensor [x]
# 3) Boron publishes signal readings to realtime database [x] [particle_boron.cpp]
# 4) Firebase cloud function handles entry to database
# 5) Corresponding new entry created in user database
# 6) Info in user database is displayed in app [x]
#
# Updates on Competition Submission or ECG Database?
#
# Homework: Find range of dates according to week numbers
#
# Set up particle boron to publish data to realtime database [particle_boron.cpp]
#
# Create Firebase Cloud Function
# - https://firebase.google.com/docs/functions/get-started?gen=2nd
# - create and test sample functions
#     - how to access written data? [sandbox/functions/main.py]
#     - deploy functions
#         - firebase deploy --only function:[FUNCTION_NAME]
#     - explore logs and menu
# - create function to move data from realtime to firestore
#
# Improve Firebase Cloud Function
# - reportID format???
# - how to submit more signals [particle_baron.cpp]
#     - convert short array to uint8_t array
#     - encode uint8_t array to base64
# - how to pass user UID [particle_boron.cpp/do_something]
#     - update particle_boron to accept arguments
#     - pass argument to realtime database entry
#
#
# ???
# compress signals and handle bytes/bits
#
# installing in firebase cloud function
# pip install --no-binary lxml lxml
#
# incompatible arm64 to x64
# https://stackoverflow.com/questions/71882029/mach-o-file-but-is-an-incompatible-architecture-have-arm64-need-x86-64-i

# %% [markdown]
# particle boron json webhooks
# https://docs.particle.io/reference/cloud-apis/webhooks/#variable-substitution
